# %% [markdown]
# **Machine Learning** é um ramo da inteligência artificial que desenvolve algoritmos capazes de aprender padrões a partir de dados, ajustando-se automaticamente sem necessidade de programação explícita para cada tarefa.
# Essa abordagem é útil em diversas aplicações do mundo real, como diagnósticos médicos, sistemas de recomendação, previsão de demanda e detecção de fraudes, pois permite que sistemas adaptem-se a novos dados e tomem decisões com base em evidências empíricas, melhorando continuamente seu desempenho.

# %% [markdown]
# ### Tipos de Machine Learning
#
# 1. **Aprendizado Supervisionado**
#    Nesse tipo, o modelo é treinado com um conjunto de dados rotulado, ou seja, os dados de entrada já vêm com as respostas corretas (rótulos). O objetivo é aprender a relação entre entrada e saída para prever ou classificar novos dados. Exemplos: regressão linear, árvores de decisão e redes neurais para classificação.
#
# 2. **Aprendizado Não-Supervisionado**
#    Aqui, o modelo trabalha com dados sem rótulos. Ele busca identificar padrões ou estruturas ocultas nos dados, como agrupamentos ou associações. É útil para explorar dados, segmentar clientes ou reduzir dimensionalidade. Exemplos: k-means, análise de componentes principais (PCA) e algoritmos de agrupamento hierárquico.

# %% [markdown]
# ### Bibliotecas Python Comuns em Machine Learning
#
# 1. **Scikit-Learn**
#    Uma das bibliotecas mais populares para Machine Learning em Python. Oferece ferramentas simples e eficientes para análise e modelagem de dados, como classificação, regressão, clustering e redução de dimensionalidade. Sua API intuitiva e ampla documentação a tornam ideal para iniciantes e projetos profissionais.
#
# 2. **TensorFlow**
#    Desenvolvida pelo Google, é usada principalmente para criar e treinar redes neurais profundas. Suporta computação distribuída e é altamente escalável, sendo amplamente utilizada em produção.
#
# 3. **Keras**
#    Uma interface de alto nível para redes neurais, que roda sobre o TensorFlow. Permite a criação rápida e fácil de modelos de deep learning com poucas linhas de código.
#
# 4. **PyTorch**
#    Desenvolvida pelo Facebook, é uma biblioteca poderosa para deep learning que se destaca pela flexibilidade e por seu modo dinâmico de construção de redes neurais, facilitando a depuração e o desenvolvimento experimental.
#
# 5. **Pandas**
#    Embora não seja exclusivamente para Machine Learning, é fundamental na etapa de pré-processamento, permitindo manipulação eficiente de dados estruturados com DataFrames, filtragens, agrupamentos e trans

# %% [markdown]
# ### Diferença entre Aprendizado Baseado em Instâncias e em Modelos
#
# - **Aprendizado Baseado em Instâncias**
#   Nesse tipo, o algoritmo memoriza os dados de treinamento e toma decisões com base na similaridade entre novas entradas e exemplos anteriores. Ele não cria um modelo generalizado, mas depende diretamente dos dados armazenados.
#   **Exemplo:** o algoritmo *K-Nearest Neighbors (KNN)*, que classifica uma nova amostra com base nas classes dos vizinhos mais próximos.
#
# - **Aprendizado Baseado em Modelos**
#   Aqui, o algoritmo constrói um modelo abstrato a partir dos dados de treinamento, aprendendo uma função que mapeia entradas para saídas. Esse modelo pode então ser usado para prever novos casos.
#   **Exemplo:** a *Regressão Linear*, que ajusta uma equação matemática para prever valores contínuos com base em variáveis de entrada.

# %% [markdown]
# ### Três Desafios Comuns em Modelos de Machine Learning
#
# 1. **Overfitting (Sobreajuste)**
#    Ocorre quando o modelo aprende tão bem os dados de treinamento que perde a capacidade de generalizar para novos dados. Ele memoriza ruídos e padrões específicos, resultando em baixa performance em testes.
#
# 2. **Dados Insuficientes ou Desequilibrados**
#    Modelos de ML precisam de grandes quantidades de dados representativos. Quando os dados são escassos ou há classes com pouca representatividade (desequilíbrio), o desempenho do modelo pode ser comprometido.
#
# 3. **Escolha e Engenharia de Features**
#    A seleção inadequada de variáveis (features) pode limitar a capacidade do modelo de aprender padrões relevantes. A engenharia de features — processo de criar e transformar variáveis — é crucial para melhorar a acurácia do modelo.

# %%
# Exercicio 6
# Primeiro eu instalei o pip install palmerpenguins

# Importar bibliotecas
import pandas as pd
from palmerpenguins import load_penguins

# Carregar o dataset
penguins = load_penguins()

# Exibir as primeiras linhas
print("Amostras do conjunto de dados:")
display(penguins.head())

# Identificar as features e o target
features = ['island', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex', 'year']
target = 'species'

print("\nFeatures (variáveis independentes):")
print(features)

print("\nTarget (variável dependente):")
print(target)

# Verificar se há dados ausentes
print("\nDados ausentes por coluna:")
print(penguins.isnull().sum())
# Out:
# Amostras do conjunto de dados:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007
# Features (variáveis independentes):
# ['island', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex', 'year']
#
# Target (variável dependente):
# species
#
# Dados ausentes por coluna:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# ...

# %%
#Exercicio 7

# Importar bibliotecas
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


# 1. Carregar e limpar os dados
penguins = load_penguins()
penguins = penguins.dropna()

# 2. Seleção de features e target (binário para simplificar)
penguins['target'] = (penguins['species'] == 'Adelie').astype(int)
features = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
X = penguins[features]
y = penguins['target']

# 3. Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.28, random_state=42)

# Mostrar tamanhos dos conjuntos
print(f"Tamanho do conjunto de treino: {X_train.shape[0]} amostras")
print(f"Tamanho do conjunto de validação: {X_val.shape[0]} amostras")
# Out:
# Tamanho do conjunto de treino: 239 amostras
# Tamanho do conjunto de validação: 67 amostras

# %%
#Exercicio 8 

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA



# 4. Criar pipeline com padronização + KNN
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=5))
])

# 5. Treinar e avaliar o modelo
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Exercicio 9

print("Relatório de Classificação:")
print(classification_report(y_test, y_pred))

# 6. Validação cruzada
scores = cross_val_score(pipeline, X, y, cv=5)
print(f"Acurácia média (5-fold CV): {scores.mean():.3f}")

# 7. Melhorias com novas features
penguins['proporcao_bico'] = penguins['bill_depth_mm'] / penguins['bill_length_mm']
penguins['comprimento_total'] = penguins['bill_length_mm'] + penguins['flipper_length_mm']
features_derivadas = ['proporcao_bico', 'comprimento_total', 'body_mass_g']
X_derivado = penguins[features_derivadas]

# 8. Novo modelo com features derivadas
X_train_d, X_test_d, y_train_d, y_test_d = train_test_split(X_derivado, y, test_size=0.25, random_state=42)
pipeline_derivado = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=5))
])
pipeline_derivado.fit(X_train_d, y_train_d)
print("Com Features Derivadas:")
print(classification_report(y_test_d, pipeline_derivado.predict(X_test_d)))

# 9. Visualização das classes com PCA
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

pca_df = pd.DataFrame(pca_result, columns=['PC1', 'PC2'])
pca_df['target'] = y.reset_index(drop=True)

plt.figure(figsize=(8, 6))
for label in [0, 1]:
    subset = pca_df[pca_df['target'] == label]
    plt.scatter(subset['PC1'], subset['PC2'], label='Adelie' if label == 1 else 'Outras', alpha=0.7)
plt.title('Visualização das classes com PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        51
#            1       0.96      1.00      0.98        43
#
#     accuracy                           0.98        94
#    macro avg       0.98      0.98      0.98        94
# weighted avg       0.98      0.98      0.98        94
#
# Acurácia média (5-fold CV): 0.982
# Com Features Derivadas:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        44
#            1       0.98      1.00      0.99        40
#
#     accuracy                           0.99        84
#    macro avg       0.99      0.99      0.99        84
# weighted avg       0.99      0.99      0.99        84

# %% [markdown]
# ### 🧠 Desafios na Construção de Modelos de Machine Learning com o Dataset Palmer Penguins
#
# A construção de um modelo de Machine Learning eficaz envolve mais do que apenas aplicar algoritmos. Ao longo dos exercícios realizados com o dataset *Palmer Penguins*, foi possível observar na prática como cada etapa do processo influencia diretamente na performance e confiabilidade do modelo final.
#
# Um dos principais desafios iniciais foi a **avaliação da qualidade dos dados**. O dataset continha valores ausentes em variáveis cruciais como comprimento do bico e massa corporal, exigindo uma etapa cuidadosa de limpeza para evitar que inconsistências contaminassem o modelo. Esse processo de filtragem foi fundamental para garantir uma base sólida de treinamento.
#
# Outro ponto crítico foi a **avaliação do peso e relevância de cada variável**. Nem todas as features possuem a mesma capacidade de separar as espécies de pinguins. Algumas, como o comprimento da nadadeira, mostraram-se altamente discriminativas, especialmente para diferenciar a espécie Gentoo. Já outras exigiram transformações para revelar padrões mais úteis. Técnicas de **engenharia de atributos**, como a criação de proporções entre medidas corporais, permitiram extrair informações adicionais dos dados originais e contribuíram para melhorar a separação entre as classes.
#
# A escolha do algoritmo também demandou atenção. O uso do **K-Nearest Neighbors (KNN)** impôs a necessidade de aplicar **padronização das variáveis**, já que o modelo depende fortemente da métrica de distância entre amostras. Sem a normalização, variáveis com maior escala dominariam a decisão do modelo, resultando em um desempenho enviesado.
#
# Durante a fase de avaliação, foi essencial ir além da acurácia. A **matriz de confusão** e as métricas de **precision**, **recall** e **f1-score** ofereceram uma análise mais detalhada dos erros cometidos, revelando onde o modelo falhava — especialmente na distinção entre Adelie e Chinstrap, que possuem características corporais similares.
#
# Por fim, técnicas como **PCA** e **t-SNE** foram empregadas para explorar visualmente a separabilidade entre as classes. Embora não contribuam diretamente para o desempenho do modelo, essas abordagens facilitaram a interpretação dos dados e ajudaram a validar as escolhas de features.
#
# Em resumo, construir um modelo de Machine Learning vai muito além da escolha do algoritmo: exige uma análise cuidadosa dos dados, aplicação criteriosa de técnicas estatísticas e atenção especial à engenharia de atributos. Cada decisão ao longo do processo impacta diretamente na robustez e na interpretabilidade do modelo final.

# %%
#Exercicio 11

# 1. Carregando os dados
penguins = load_penguins()
penguins = penguins.dropna()

# 2. Novo target: Gentoo = 1, outras = 0
penguins['target_gentoo'] = (penguins['species'] == 'Gentoo').astype(int)

# 3. Seleção das features
features = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
X = penguins[features]
y = penguins['target_gentoo']

# 4. Divisão treino/teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# 5. Pipeline com padronização e KNN
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=5))
])

pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# 6. Avaliação do modelo
print("Relatório de Classificação - Gentoo vs Outras:")
print(classification_report(y_test, y_pred))

# 7. Validação cruzada
scores = cross_val_score(pipeline, X, y, cv=5)
print(f"Acurácia média (5-fold CV): {scores.mean():.3f}")

# 8. Matriz de Confusão
cm = confusion_matrix(y_test, y_pred, labels=[1, 0])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Gentoo', 'Outras'])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - Gentoo vs Outras")
plt.show()
# Out:
# Relatório de Classificação - Gentoo vs Outras:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Acurácia média (5-fold CV): 1.000

# %%
#Reeimplementação completa para realizar o exercicio 12

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.decomposition import PCA

# Carrega o dataset
penguins = sns.load_dataset("penguins").dropna()

# Define features e alvo
features = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
X = penguins[features]
y = penguins['species']

# Divide em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Cria pipeline com padronização + KNN
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=5))
])

# Treina o modelo
pipeline.fit(X_train, y_train)

# Faz previsões
y_pred = pipeline.predict(X_test)

# Relatório de classificação
print("Relatório de Classificação:\n")
print(classification_report(y_test, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_test, y_pred, labels=pipeline.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - KNN Multiclasse")
plt.show()

# Visualização com PCA
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
pca_df['species'] = y.values

plt.figure(figsize=(8, 6))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='species', palette='Set1')
plt.title("Visualização das Espécies com PCA")
plt.grid(True)
plt.show()
# Out:
# Relatório de Classificação:
#
#               precision    recall  f1-score   support
#
#       Adelie       0.98      1.00      0.99        40
#    Chinstrap       1.00      0.93      0.97        15
#       Gentoo       1.00      1.00      1.00        29
#
#     accuracy                           0.99        84
#    macro avg       0.99      0.98      0.98        84
# weighted avg       0.99      0.99      0.99        84

# %%
# Importar biblioteca para visualização
import matplotlib.pyplot as plt

# Testar diferentes valores de k para encontrar o melhor
k_values = list(range(1, 21))  # Testaremos k de 1 a 20
accuracies = []

# Loop para treinar e avaliar o modelo para cada valor de k
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_val_scaled)
    acc = accuracy_score(y_val, y_pred)
    accuracies.append(acc)

# Visualizar a acurácia em função do número de vizinhos (k)
plt.figure(figsize=(10, 5))
plt.plot(k_values, accuracies, marker='o')
plt.title('Ajuste de Hiperparâmetro: Número de Vizinhos (k)')
plt.xlabel('Número de Vizinhos (k)')
plt.ylabel('Acurácia no Conjunto de Validação')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %%
# Importar função para matriz de confusão e visualização
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Re-treinar o modelo com o melhor valor de k encontrado

melhor_k = k_values[accuracies.index(max(accuracies))]
knn_otimizado = KNeighborsClassifier(n_neighbors=melhor_k)
knn_otimizado.fit(X_train_scaled, y_train)

# Fazer previsões com o modelo final
y_pred_otimizado = knn_otimizado.predict(X_val_scaled)

# Avaliar o desempenho final do modelo com o k otimizado
print("Acurácia com k otimizado:", accuracy_score(y_val, y_pred_otimizado))
print("\nRelatório de Classificação:")
print(classification_report(y_val, y_pred_otimizado, target_names=["Não-Adelie", "Adelie"]))

# Gerar a matriz de confusão
cm = confusion_matrix(y_val, y_pred_otimizado)

# Exibir a matriz de confusão com rótulos
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Não-Adelie", "Adelie"])
disp.plot(cmap='Blues', values_format='d')
plt.title(f'Matriz de Confusão (k = {melhor_k})')
plt.show()
# Out:
# Acurácia com k otimizado: 0.9880952380952381
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#   Não-Adelie       0.98      1.00      0.99        47
#       Adelie       1.00      0.97      0.99        37
#
#     accuracy                           0.99        84
#    macro avg       0.99      0.99      0.99        84
# weighted avg       0.99      0.99      0.99        84

# %%
# Avaliar a acurácia do modelo final nos dados de validação
# Esse valor representa o percentual de acertos do classificador KNN com o melhor k encontrado
acuracia_final = accuracy_score(y_val, y_pred_otimizado)
print(f"Acurácia final do modelo KNN nos dados de validação: {acuracia_final:.4f}")
# Out:
# Acurácia final do modelo KNN nos dados de validação: 0.9881

# %% [markdown]
# ### Discussão: Desafios e Etapas Cruciais na Criação de um Modelo de Machine Learning
#
# Durante a criação do modelo de Machine Learning com a base de dados "Pinguins", enfrentamos diversos desafios comuns no processo de modelagem. Um dos primeiros obstáculos foi lidar com dados ausentes, que precisaram ser removidos para evitar distorções no treinamento. A escolha adequada das features também se mostrou essencial, pois variáveis irrelevantes ou mal preparadas impactam negativamente o desempenho do modelo.
#
# Outro ponto crítico foi o balanceamento entre **underfitting** e **overfitting**, resolvido parcialmente pelo ajuste do hiperparâmetro `k` no algoritmo KNN. A etapa de padronização dos dados foi vital, dado que o KNN é altamente sensível às escalas das variáveis.
#
# Cada etapa — desde a análise exploratória, pré-processamento, divisão dos dados, até o ajuste de hiperparâmetros — teve papel fundamental para garantir que o modelo aprendesse padrões reais e generalizáveis. A avaliação com métricas como acurácia e a matriz de confusão permitiu identificar acertos e falhas, fornecendo base para futuras melhorias. Assim, fica evidente que o sucesso de um projeto de Machine Learning depende diretamente da atenção cuidadosa a cada uma dessas fases.

# %%
# Reavaliar acurácias de treino e validação para vários valores de k
train_accuracies = []
val_accuracies = []
k_range = list(range(1, 21))  # Testar k de 1 a 20

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)

    # Acurácia no treino
    train_acc = accuracy_score(y_train, knn.predict(X_train_scaled))
    train_accuracies.append(train_acc)

    # Acurácia na validação
    val_acc = accuracy_score(y_val, knn.predict(X_val_scaled))
    val_accuracies.append(val_acc)

# Plotar gráfico de acurácia no treino vs validação
plt.figure(figsize=(10, 5))
plt.plot(k_range, train_accuracies, marker='o', label='Treino')
plt.plot(k_range, val_accuracies, marker='s', label='Validação')
plt.title('Diagnóstico de Underfitting e Overfitting')
plt.xlabel('Número de Vizinhos (k)')
plt.ylabel('Acurácia')
plt.xticks(k_range)
plt.legend()
plt.grid(True)
plt.show()

# %%
# Foco nos valores de k com melhor desempenho observado anteriormente
k_otimos = [3, 4, 5]
melhor_k_otimo = None
melhor_acc_val = 0
melhor_modelo = None

# Testar os valores ótimos de k identificados
for k in k_otimos:
    knn_temp = KNeighborsClassifier(n_neighbors=k)
    knn_temp.fit(X_train_scaled, y_train)

    acc_val = accuracy_score(y_val, knn_temp.predict(X_val_scaled))
    acc_treino = accuracy_score(y_train, knn_temp.predict(X_train_scaled))
    
    print(f"k = {k} | Acurácia Treino: {acc_treino:.4f} | Validação: {acc_val:.4f}")

    if acc_val > melhor_acc_val:
        melhor_k_otimo = k
        melhor_acc_val = acc_val
        melhor_modelo = knn_temp

print(f"\n🔎 Melhor valor final de k: {melhor_k_otimo}")
# Out:
# k = 3 | Acurácia Treino: 0.9960 | Validação: 0.9762
# k = 4 | Acurácia Treino: 1.0000 | Validação: 0.9881
# k = 5 | Acurácia Treino: 0.9880 | Validação: 0.9881
#
# 🔎 Melhor valor final de k: 4

# %%
# Fazer previsões com o melhor modelo
y_pred_final = melhor_modelo.predict(X_val_scaled)

# Avaliar o desempenho final
print("\n✅ Avaliação do Modelo Ajustado:")
print("Acurácia:", accuracy_score(y_val, y_pred_final))
print("\nRelatório de Classificação:")
print(classification_report(y_val, y_pred_final, target_names=["Não-Adelie", "Adelie"]))

# Matriz de confusão
cm_final = confusion_matrix(y_val, y_pred_final)
disp_final = ConfusionMatrixDisplay(confusion_matrix=cm_final, display_labels=["Não-Adelie", "Adelie"])
disp_final.plot(cmap='Blues', values_format='d')
plt.title(f'Matriz de Confusão Final (k = {melhor_k_otimo})')
plt.show()
# Out:
# ✅ Avaliação do Modelo Ajustado:
# Acurácia: 0.9880952380952381
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#   Não-Adelie       0.98      1.00      0.99        47
#       Adelie       1.00      0.97      0.99        37
#
#     accuracy                           0.99        84
#    macro avg       0.99      0.99      0.99        84
# weighted avg       0.99      0.99      0.99        84

# %%
# Redefinir as variáveis
X_gentoo = penguins_g[features_numericas]
y_gentoo = penguins_g['target_gentoo']

# Separar os dados
X_train_g, X_val_g, y_train_g, y_val_g = train_test_split(
    X_gentoo, y_gentoo, test_size=0.2, random_state=42, stratify=y_gentoo
)

# Padronizar
scaler_g = StandardScaler()
X_train_g_scaled = scaler_g.fit_transform(X_train_g)
X_val_g_scaled = scaler_g.transform(X_val_g)

# Treinar modelo
knn_gentoo = KNeighborsClassifier(n_neighbors=melhor_k_otimo)
knn_gentoo.fit(X_train_g_scaled, y_train_g)

# Avaliar
y_pred_g = knn_gentoo.predict(X_val_g_scaled)

# Métricas
print("🔎 Acurácia do modelo Gentoo vs. outros:")
print("Acurácia:", accuracy_score(y_val_g, y_pred_g))
print("\nRelatório de Classificação:")
print(classification_report(y_val_g, y_pred_g, target_names=["Não-Gentoo", "Gentoo"]))

# Matriz de confusão
cm_g = confusion_matrix(y_val_g, y_pred_g)
disp_g = ConfusionMatrixDisplay(confusion_matrix=cm_g, display_labels=["Não-Gentoo", "Gentoo"])
disp_g.plot(cmap='Blues', values_format='d')
plt.title(f'Matriz de Confusão - Gentoo vs. Outros (k = {melhor_k_otimo})')
plt.show()
# Out:
# 🔎 Acurácia do modelo Gentoo vs. outros:
# Acurácia: 1.0
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#   Não-Gentoo       1.00      1.00      1.00        44
#       Gentoo       1.00      1.00      1.00        25
#
#     accuracy                           1.00        69
#    macro avg       1.00      1.00      1.00        69
# weighted avg       1.00      1.00      1.00        69

# %%
# Garantir que estamos com os dados numéricos e sem NaNs
penguins_multi = penguins.dropna(subset=features_numericas + ['species'])

# Features e target para multiclasse
X_multi = penguins_multi[features_numericas]
y_multi = penguins_multi['species']  # target com 3 classes: Adelie, Chinstrap, Gentoo

# Dividir treino e validação
X_train_m, X_val_m, y_train_m, y_val_m = train_test_split(
    X_multi, y_multi, test_size=0.2, random_state=42, stratify=y_multi
)

# Padronizar os dados
scaler_m = StandardScaler()
X_train_m_scaled = scaler_m.fit_transform(X_train_m)
X_val_m_scaled = scaler_m.transform(X_val_m)

# Treinar o modelo com KNN (k = 4, baseado em análise anterior)
knn_multi = KNeighborsClassifier(n_neighbors=melhor_k_otimo)
knn_multi.fit(X_train_m_scaled, y_train_m)

# Prever e avaliar
y_pred_m = knn_multi.predict(X_val_m_scaled)

# Métricas e matriz de confusão
print("🔎 Acurácia do modelo Multiclasse (3 espécies):")
print("Acurácia:", accuracy_score(y_val_m, y_pred_m))
print("\nReatório de Classificação:")
print(classification_report(y_val_m, y_pred_m))

# Matriz de confusão
cm_m = confusion_matrix(y_val_m, y_pred_m, labels=knn_multi.classes_)
disp_m = ConfusionMatrixDisplay(confusion_matrix=cm_m, display_labels=knn_multi.classes_)
disp_m.plot(cmap='Blues', values_format='d')
plt.title(f'Matriz de Confusão - Classificação Multiclasse (k = {melhor_k_otimo})')
plt.show()
# Out:
# 🔎 Acurácia do modelo Multiclasse (3 espécies):
# Acurácia: 1.0
#
# Reatório de Classificação:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        29
#    Chinstrap       1.00      1.00      1.00        14
#       Gentoo       1.00      1.00      1.00        24
#
#     accuracy                           1.00        67
#    macro avg       1.00      1.00      1.00        67
# weighted avg       1.00      1.00      1.00        67

# %% [markdown]
# ### 🧠 Conclusão Crítica sobre a Classificação das Três Espécies de Pinguins
#
# Embora o modelo KNN tenha alcançado **acurácia perfeita (100%)** na tarefa de classificar as três espécies de pinguins (*Adelie*, *Chinstrap* e *Gentoo*), é importante interpretar esse resultado com cautela.
#
# A espécie **Gentoo** possui características morfológicas muito distintas — como nadadeiras mais longas e maior massa corporal — o que facilita sua separação em relação às demais. Já a diferenciação entre **Adelie** e **Chinstrap** é mais desafiadora, pois ambas compartilham valores próximos em diversas variáveis.
#
# Além disso, a acurácia perfeita pode ter sido favorecida por:
# - Um **particionamento treino/validação** com separações bem definidas;
# - Um conjunto de validação **relativamente pequeno**;
# - O fato de o KNN ser altamente dependente da distribuição espacial dos dados.
#
# Portanto, para validar a robustez do modelo, é fundamental realizar:
# - **Validação cruzada (cross-validation)**;
# - **Visualizações de separação das classes** via técnicas como PCA ou t-SNE.
#
# Essas abordagens fornecem uma visão mais confiável sobre a capacidade real de generalização do modelo.

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# Padronizar os dados
X_scaled = StandardScaler().fit_transform(X_multi)

# PCA - redução para 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Plot com PCA
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y_multi)
plt.title("Separação das Espécies com PCA (2D)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid(True)
plt.show()

# t-SNE - alternativa não-linear
X_tsne = TSNE(n_components=2, random_state=42, perplexity=30).fit_transform(X_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=y_multi)
plt.title("Separação das Espécies com t-SNE (2D)")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Comparar a nova variável 'comprimento_total'
plt.figure(figsize=(10, 5))
sns.boxplot(x='species', y='comprimento_total', data=penguins_ac)
plt.title('Distribuição do Comprimento Total (bico + nadadeira)')
plt.show()

# Comparar a proporção bico/nadadeira por sexo
plt.figure(figsize=(10, 5))
sns.boxplot(x='species', y='proporcao_bico_nadadeira', hue='sex', data=penguins_ac)
plt.title('Proporção Bico/Nadadeira por Espécie e Sexo')
plt.show()

# Scatterplot entre as novas variáveis
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x='comprimento_total',
    y='proporcao_bico_nadadeira',
    hue='species',
    style='sex',
    data=penguins_ac
)
plt.title('Separação entre Adelie e Chinstrap com Variáveis Derivadas')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# Filtrar apenas Adelie e Chinstrap
penguins_ac = penguins.dropna(subset=features_numericas + ['species', 'sex'])
penguins_ac = penguins_ac[penguins_ac['species'].isin(['Adelie', 'Chinstrap'])]

# Criar features derivadas
penguins_ac['comprimento_total'] = penguins_ac['bill_length_mm'] + penguins_ac['flipper_length_mm']
penguins_ac['proporcao_bico_nadadeira'] = penguins_ac['bill_depth_mm'] / penguins_ac['flipper_length_mm']

# Separar os dois conjuntos de features
features_originais = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
features_derivadas = ['comprimento_total', 'proporcao_bico_nadadeira']
y_tsne = penguins_ac['species']

# Escalar os dois conjuntos
X_orig = StandardScaler().fit_transform(penguins_ac[features_originais])
X_deriv = StandardScaler().fit_transform(penguins_ac[features_derivadas])

# Aplicar t-SNE nos dois conjuntos
X_tsne_orig = TSNE(n_components=2, random_state=42, perplexity=10).fit_transform(X_orig)
X_tsne_deriv = TSNE(n_components=2, random_state=42, perplexity=10).fit_transform(X_deriv)

# Plot lado a lado
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.scatterplot(x=X_tsne_orig[:, 0], y=X_tsne_orig[:, 1], hue=y_tsne, ax=axs[0])
axs[0].set_title("t-SNE com Features Originais")

sns.scatterplot(x=X_tsne_deriv[:, 0], y=X_tsne_deriv[:, 1], hue=y_tsne, ax=axs[1])
axs[1].set_title("t-SNE com Features Derivadas")

for ax in axs:
    ax.grid(True)
    ax.set_xlabel("Dimensão 1")
    ax.set_ylabel("Dimensão 2")

plt.suptitle("Comparação Adelie vs. Chinstrap - t-SNE (Originais vs. Derivadas)", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
# Importar bibliotecas para padronização, modelo KNN e métricas de avaliação
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# Padronizar os dados de treino e validação
# Isso é essencial para o algoritmo KNN, pois ele depende da distância entre os pontos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Criar o classificador KNN com k=5 (padrão comum para início de testes)
# O modelo buscará os 5 vizinhos mais próximos para decidir a classe de uma nova amostra
knn = KNeighborsClassifier(n_neighbors=5)

# Treinar o modelo com os dados de treino
knn.fit(X_train_scaled, y_train)

# Fazer previsões com os dados de validação
y_pred = knn.predict(X_val_scaled)

# Avaliar a acurácia do modelo (percentual de acertos no conjunto de validação)
print("Acurácia do modelo:", accuracy_score(y_val, y_pred))

# Imprimir relatório detalhado com precisão, recall e F1-score para cada classe
print("\nRelatório de Classificação:")
print(classification_report(y_val, y_pred, target_names=["Não-Adelie", "Adelie"]))
# Out:
# Acurácia do modelo: 0.9880952380952381
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#   Não-Adelie       1.00      0.98      0.99        47
#       Adelie       0.97      1.00      0.99        37
#
#     accuracy                           0.99        84
#    macro avg       0.99      0.99      0.99        84
# weighted avg       0.99      0.99      0.99        84

# %%
# Usar features derivadas como base para t-SNE
features_novas = ['comprimento_total', 'proporcao_bico_nadadeira']
X_derivadas = penguins_ac[features_novas]
y_derivadas = penguins_ac['species']

# Padronizar
X_derivadas_scaled = StandardScaler().fit_transform(X_derivadas)

# Aplicar t-SNE
X_tsne_derivadas = TSNE(n_components=2, random_state=42, perplexity=10).fit_transform(X_derivadas_scaled)

# Visualizar
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_tsne_derivadas[:, 0], y=X_tsne_derivadas[:, 1], hue=y_derivadas)
plt.title("Separação Adelie vs. Chinstrap com t-SNE (features derivadas)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 🧪 Comparação: Separação com t-SNE usando Features Originais vs. Derivadas
#
# Para avaliar a dificuldade de distinguir entre Adelie e Chinstrap, utilizamos a técnica de redução de dimensionalidade t-SNE com dois conjuntos de variáveis:
#
# - **t-SNE com features originais (4 variáveis):**
#   Mostra que Gentoo é facilmente separável, mas Adelie e Chinstrap aparecem mais próximas entre si, com possíveis sobreposições.
#
# - **t-SNE com features derivadas (`comprimento_total`, `proporcao_bico_nadadeira`):**
#   Foca apenas em Adelie vs. Chinstrap e evidencia uma separação mais clara entre as duas espécies, com menos sobreposição. Isso confirma que a criação de variáveis combinadas pode destacar melhor as diferenças entre classes próximas.
#
# Esse resultado reforça que **engenharia de features pode aumentar significativamente a capacidade de generalização e separação do modelo**.
